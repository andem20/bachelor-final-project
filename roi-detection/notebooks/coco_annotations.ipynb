# %%
import pandas as pd 
import json
import numpy as np
import datetime
import re
import copy

# %%
df = pd.read_csv("../../dataset/preprocessed-datasets/preprocessed_metadata.csv")
df.head()
# Out:
#    Unnamed: 0  index patient_id  breast_density left_or_right_breast
# 0           0      0    P_00001               3                 LEFT  \
# 1           1      1    P_00001               3                 LEFT
# 2           2      2    P_00004               3                 LEFT
# 3           3      3    P_00004               3                 LEFT
# 4           4      4    P_00004               3                RIGHT
#
#   image_view  abnormality_id abnormality_type
# 0         CC               1             mass  \
# 1        MLO               1             mass
# 2         CC               1             mass
# 3        MLO               1             mass
# 4        MLO               1             mass
#
#                                 shape         margin  ...
# 0  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED  ...  \
# 1  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED  ...
# 2            ARCHITECTURAL_DISTORTION    ILL_DEFINED  ...
# 3            ARCHITECTURAL_DISTORTION    ILL_DEFINED  ...
# 4                                OVAL  CIRCUMSCRIBED  ...
#
#                            checksum is_flipped  vertical_crop_pixels
# 0  8edd908901f92930776353c9ed140d95      False                   480  \
# 1  d15f9840224eafd79870dc700c2e6cb1      False                   480
# 2  17b97fe9529c1f9777fbf031fdfe7909       True                   549
# 3  39a6e98a61aa8e2c19b3136c48e1cc07       True                   549
# 4  baf98767e0ca955c78f41c147077435e      False                   549
#
#   horizontal_crop_pixels width height
# 0                   1918  1918   3848  \
# 1                   2138  2138   3840
# 2                   2277  2277   4393
# 3                   2151  2151   4393
# 4                   2113  2113   4393
#
#                     preprocessed_original_image_path num_masks
# 0  preprocessed/8edd908901f92930776353c9ed140d95.png         1  \
# 1  preprocessed/d15f9840224eafd79870dc700c2e6cb1.png         1
# 2  preprocessed/17b97fe9529c1f9777fbf031fdfe7909.png         1
# 3  preprocessed/39a6e98a61aa8e2c19b3136c48e1cc07.png         1
# 4  preprocessed/baf98767e0ca955c78f41c147077435e.png         1
#
#                                       bounding_boxes
# 0  [{"x": 270, "y": 1942, "width": 390, "height":...  \
# 1  [{"x": 271, "y": 2500, "width": 215, "height":...
# 2  [{"x": 1186, "y": 2951, "width": 382, "height"...
# 3  [{"x": 1011, "y": 2506, "width": 381, "height"...
# 4  [{"x": 694, "y": 3255, "width": 424, "height":...
#
#                      preprocessed_mass_all_mask_path
# 0  preprocessed/8edd908901f92930776353c9ed140d95_...
# 1  preprocessed/d15f9840224eafd79870dc700c2e6cb1_...
# 2  preprocessed/17b97fe9529c1f9777fbf031fdfe7909_...
# 3  preprocessed/39a6e98a61aa8e2c19b3136c48e1cc07_...
# 4  preprocessed/baf98767e0ca955c78f41c147077435e_...
#
# [5 rows x 27 columns]

# %% [markdown]
# # Genrate COCO format dataset
# - Find bounding boxes
# - Create dict
# - Save as json

# %%
coco = {
    "info": {
        "description": "CBIS-DDCM dataset",
        "version": "1.0",
        "year": 2023,
        "date_created": "2023/19/03",
        "samples": 0
    },
    "licenses": [
        {
            "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/",
            "id": 1,
            "name": "Attribution-NonCommercial-ShareAlike License"
        }
    ],
    "categories": [
        {
            "id": 0,
            "name": "ROI",
            "supercategory": "none"
        },
        {
            "id": 1,
            "name": "Mass",
            "supercategory": "ROI"
        },
        {
            "id": 2,
            "name": "Calcification",
            "supercategory": "ROI"
        },
    ],
    "images": [
        # {
        #     "id": 0,
        #     "license": 1,
        #     "file_name": "BloodImage_00204_jpg.rf.04ba9998769a12d374e6c4b284e6a4a2.jpg",
        #     "height": 416,
        #     "width": 416,
        #     "date_captured": "2021-02-24T08:05:45+00:00"
        # }
    ],
    "annotations": [
        # {
        #     "id": 0,
        #     "image_id": 0,
        #     "category_id": 2,
        #     "bbox": [
        #         "x",
        #         "y",
        #         "width",
        #         "height"
        #     ],
        #     "area": 5934,
        #     "segmentation": [],
        #     "iscrowd": 0
        # }
    ]
}

# %%
classes = {
    "mass": 1,
    "calcification": 2
}

# %%
df['bounding_boxes'] = df['bounding_boxes'].apply(json.loads)

# %%
train_df = df.query("dataset == 'train'")
test_df = df.query("dataset == 'test'")

print(len(train_df), len(test_df))
# Out:
# 1231 361

# %% [markdown]
# ### Add images and bounding boxes to dict

# %%
def create_coco(df, coco):
    images = []
    annotations = []

    for i, row in df.iterrows():
        image = {
            "id": i,
            "license": 1,
            "file_name": row.preprocessed_original_image_path.split("/")[-1],
            "height": row.height,
            "width": row.width,
            "date_captured": str(datetime.datetime.now())
        }

        has_annotations = False

        for bbox in row.bounding_boxes:
            if bbox["type"] == "calcification":
                continue
            
            has_annotations = True
            x, y, width, height = bbox["x"], bbox["y"], bbox["width"], bbox["height"]
            annotation = {
                "id": len(annotations),
                "image_id": i,
                "category_id": classes[bbox["type"]],
                "bbox": [int(x), int(y), int(width), int(height)],
                "area": int(width * height),
                "segmentation": [],
                "iscrowd": 0
            }
            
            annotations.append(annotation)
            
        if not has_annotations:
            continue 

        images.append(image)

    coco["images"] = images
    coco["annotations"] = annotations
    coco["info"]["samples"] = len(images)

    return coco

# %%
train_coco_1 = create_coco(train_df, copy.deepcopy(coco))
test_coco = create_coco(test_df, copy.deepcopy(coco))

# %% [markdown]
# ### Save COCO dataset to JSON

# %%
with open("../annotations/_train_annotations_1.coco.json", "w") as f:
    f.write(json.dumps(train_coco_1))

with open("../annotations/_test_annotations.coco.json", "w") as f:
    f.write(json.dumps(test_coco))
